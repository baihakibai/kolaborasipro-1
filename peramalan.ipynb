# %% [markdown]
# Proyek Sains Data C
# Nama : M. Ilham Anggis Bangkit Pamungkas
# NIM : 200411100197
# Nama : Baihaki
# NIM : 200411100181
#
# Github : https://github.com/M-ILHAM-197/kolaborasipro

# %%
# !pip install pandas

# %%
import numpy as np
from numpy import  array

# %%
import pandas as pd
df = pd.read_csv('airline-passengers.csv')
df
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]

# %%
X_train = df.iloc[:115]  # Baris 0-2
X_test = df.iloc[115:]

# %%
# !pip install scikit-learn

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

X_train_norm = X_train[['Passengers']]
X_test_norm = X_test[['Passengers']]
X_train_norm = scaler.fit_transform(X_train_norm)
X_test_norm = scaler.fit_transform(X_test_norm)

# Mengganti nilai kolom asli dengan nilai yang telah dinormalisasi
X_train[['Passengers']] = X_train_norm
X_test[['Passengers']] = X_test_norm

# Menyimpan data yang telah dinormalisasi ke file CSV baru
print(X_train)
print(X_test)
# Out:
#        Month  Passengers
# 0    1949-01    0.020672
# 1    1949-02    0.036176
# 2    1949-03    0.072351
# 3    1949-04    0.064599
# 4    1949-05    0.043928
# ..       ...         ...
# 110  1958-03    0.666667
# 111  1958-04    0.630491
# 112  1958-05    0.669251
# 113  1958-06    0.855297
# 114  1958-07    1.000000
#
# [115 rows x 2 columns]
#        Month  Passengers
# 115  1958-08    0.625000
# 116  1958-09    0.301282
# 117  1958-10    0.157051
# 118  1958-11    0.000000
# 119  1958-12    0.086538
# 120  1959-01    0.160256
# 121  1959-02    0.102564
# 122  1959-03    0.307692
# 123  1959-04    0.275641
# 124  1959-05    0.352564
# 125  1959-06    0.519231
# 126  1959-07    0.762821
# 127  1959-08    0.798077
# 128  1959-09    0.490385
# 129  1959-10    0.310897
# 130  1959-11    0.166667
# 131  1959-12    0.304487
# 132  1960-01    0.342949
# 133  1960-02    0.259615
# 134  1960-03    0.349359
# 135  1960-04    0.483974
# 136  1960-05    0.519231
# 137  1960-06    0.721154
# ...

# %%
sc = MinMaxScaler(feature_range = (0, 1))
scaled = sc.fit_transform(np.reshape(X_train['Passengers'],(-1,1)))
df = pd.DataFrame(scaled, columns=["Normalize"])
df
# df = pd.DataFrame(scaled)
# df
# Out:
#      Normalize
# 0     0.020672
# 1     0.036176
# 2     0.072351
# 3     0.064599
# 4     0.043928
# ..         ...
# 110   0.666667
# 111   0.630491
# 112   0.669251
# 113   0.855297
# 114   1.000000
#
# [115 rows x 1 columns]

# %%
scaled
# Out:
# array([[0.02067183],
#        [0.03617571],
#        [0.07235142],
#        [0.06459948],
#        [0.04392765],
#        [0.08010336],
#        [0.11369509],
#        [0.11369509],
#        [0.08268734],
#        [0.03875969],
#        [0.        ],
#        [0.03617571],
#        [0.02842377],
#        [0.05684755],
#        [0.09560724],
#        [0.08010336],
#        [0.05426357],
#        [0.11627907],
#        [0.17054264],
#        [0.17054264],
#        [0.13953488],
#        [0.0749354 ],
#        [0.02583979],
#        [0.09302326],
#        [0.10594315],
#        [0.11886305],
#        [0.19121447],
#        [0.15245478],
#        [0.17571059],
#        [0.19121447],
#        [0.24547804],
#        [0.24547804],
#        [0.20671835],
#        [0.1498708 ],
#        [0.10852713],
#        [0.16020672],
#        [0.17312661],
#        [0.19638243],
#        [0.22997416],
#        [0.19896641],
#        [0.20413437],
#        [0.29457364],
#        [0.3255814 ],
# ...

# %%
def split_sequence(sequence, n_steps):
  X, y = list(), list()
  for i in range(len(sequence)):
    # find the end of this pattern
    end_ix = i + n_steps
  # check if we are beyond the sequence
    if end_ix > len(sequence)-1:
      break
    # gather input and output parts of the pattern
    seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
    X.append(seq_x)
    y.append(seq_y)
  return array(X), array(y)

# %%
X, y = split_sequence(scaled, 2)
print(X.shape, y.shape)
shapeX = np.reshape(X,(113,2))

dfX = pd.DataFrame(shapeX, columns=["Xt-2", "Xt-1"])
dfy = pd.DataFrame(y, columns=["Xt"])

df = pd.concat((dfX, dfy), axis = 1)
df
# Out:
# (113, 2, 1) (113, 1)
#          Xt-2      Xt-1        Xt
# 0    0.020672  0.036176  0.072351
# 1    0.036176  0.072351  0.064599
# 2    0.072351  0.064599  0.043928
# 3    0.064599  0.043928  0.080103
# 4    0.043928  0.080103  0.113695
# ..        ...       ...       ...
# 108  0.609819  0.552972  0.666667
# 109  0.552972  0.666667  0.630491
# 110  0.666667  0.630491  0.669251
# 111  0.630491  0.669251  0.855297
# 112  0.669251  0.855297  1.000000
#
# [113 rows x 3 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor
